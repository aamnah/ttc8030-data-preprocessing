# %% [markdown]
# ## Exercise 2 - Pandas part 2

# %% [markdown]
# **Note**: Throughout the exercise, the original data frame is to be processed!

# %% [markdown]
# 1 Read the content of the `data_export.csv` file saved at the end of the previous exercise into the dataframe so that the `Unnamed 0` column is not created when the file is read.

# %%
import pandas as pd

# df = pd.read_csv("./data_export.csv", usecols= lambda col: col != 'Unnamed: 0')
df = pd.read_csv("./data_export.csv", index_col=[0])
df
# Out:
#      column1   column2   column3
# 0        NaN  0.380058  0.919389
# 1   0.922251  0.490721  0.133932
# 3   0.363707  0.878349  0.485700
# 6   0.323134  0.036466  0.186775
# 7   0.467610  0.850993  0.377558
# 8   0.303299  0.096971  0.451031
# 9   0.733485  0.591996  0.658924
# 10  0.641628  0.251886  0.274987
# 12  0.319906  0.489200  0.990319
# 13  0.780267  0.458454  0.053428
# 15  0.935875  0.698276  0.446885
# 17  0.273193  0.300307  0.768270
# 18  0.467060  0.225161  0.911570
# 20  0.300589  0.455980  0.292225
# 21  0.859970  0.346539  0.364629
# 22  0.842364  0.093485  0.662066
# 23  0.781693  0.573344  0.815692
# 24  0.788949  0.945625  0.852690

# %% [markdown]
# 2 Drop the rows with `NaN` values.

# %%
# axis=0 means rows, axis=1 means columns
df.dropna(axis=0, inplace=True)
df
# Out:
#      column1   column2   column3
# 1   0.922251  0.490721  0.133932
# 3   0.363707  0.878349  0.485700
# 6   0.323134  0.036466  0.186775
# 7   0.467610  0.850993  0.377558
# 8   0.303299  0.096971  0.451031
# 9   0.733485  0.591996  0.658924
# 10  0.641628  0.251886  0.274987
# 12  0.319906  0.489200  0.990319
# 13  0.780267  0.458454  0.053428
# 15  0.935875  0.698276  0.446885
# 17  0.273193  0.300307  0.768270
# 18  0.467060  0.225161  0.911570
# 20  0.300589  0.455980  0.292225
# 21  0.859970  0.346539  0.364629
# 22  0.842364  0.093485  0.662066
# 23  0.781693  0.573344  0.815692
# 24  0.788949  0.945625  0.852690

# %% [markdown]
# 3 Change all values ​​in the fifth and tenth row to `NaN`.

# %%
df.iloc[[4, 9],:] = float('NaN')
df
# Out:
#      column1   column2   column3
# 1   0.922251  0.490721  0.133932
# 3   0.363707  0.878349  0.485700
# 6   0.323134  0.036466  0.186775
# 7   0.467610  0.850993  0.377558
# 8        NaN       NaN       NaN
# 9   0.733485  0.591996  0.658924
# 10  0.641628  0.251886  0.274987
# 12  0.319906  0.489200  0.990319
# 13  0.780267  0.458454  0.053428
# 15       NaN       NaN       NaN
# 17  0.273193  0.300307  0.768270
# 18  0.467060  0.225161  0.911570
# 20  0.300589  0.455980  0.292225
# 21  0.859970  0.346539  0.364629
# 22  0.842364  0.093485  0.662066
# 23  0.781693  0.573344  0.815692
# 24  0.788949  0.945625  0.852690

# %% [markdown]
# 4 Print the number of `NaN` values ​​in each column from the DataFrame object.

# %%
df.isna().sum()
# Out:
# column1    2
# column2    2
# column3    2
# dtype: int64

# %% [markdown]
# 5 Fill in the `NaN` values ​​made above with linear interpolation.

# %%
df.interpolate(method='linear', inplace=True)
df
# Out:
#      column1   column2   column3
# 1   0.922251  0.490721  0.133932
# 3   0.363707  0.878349  0.485700
# 6   0.323134  0.036466  0.186775
# 7   0.467610  0.850993  0.377558
# 8   0.600548  0.721495  0.518241
# 9   0.733485  0.591996  0.658924
# 10  0.641628  0.251886  0.274987
# 12  0.319906  0.489200  0.990319
# 13  0.780267  0.458454  0.053428
# 15  0.526730  0.379381  0.410849
# 17  0.273193  0.300307  0.768270
# 18  0.467060  0.225161  0.911570
# 20  0.300589  0.455980  0.292225
# 21  0.859970  0.346539  0.364629
# 22  0.842364  0.093485  0.662066
# 23  0.781693  0.573344  0.815692
# 24  0.788949  0.945625  0.852690

# %% [markdown]
# 6 Change the last value of `column1` to 94 and the last value of `column3` to 45.

# %%
df.column1.iloc[-1] = 94
df.column3.iloc[-1] = 45

df
# Out:
#       column1   column2    column3
# 1    0.922251  0.490721   0.133932
# 3    0.363707  0.878349   0.485700
# 6    0.323134  0.036466   0.186775
# 7    0.467610  0.850993   0.377558
# 8    0.600548  0.721495   0.518241
# 9    0.733485  0.591996   0.658924
# 10   0.641628  0.251886   0.274987
# 12   0.319906  0.489200   0.990319
# 13   0.780267  0.458454   0.053428
# 15   0.526730  0.379381   0.410849
# 17   0.273193  0.300307   0.768270
# 18   0.467060  0.225161   0.911570
# 20   0.300589  0.455980   0.292225
# 21   0.859970  0.346539   0.364629
# 22   0.842364  0.093485   0.662066
# 23   0.781693  0.573344   0.815692
# 24  94.000000  0.945625  45.000000

# %% [markdown]
# 7 Add a new column called `column4` to the DataFrame object. This column should include the sum of the columns `column1` and `column3`.

# %%
# df = df.assign(column4 = lambda x: x.column1 + x.column3)

df["column4"] = df["column1"] + df["column3"]
df
# Out:
#       column1   column2    column3     column4
# 1    0.922251  0.490721   0.133932    1.056182
# 3    0.363707  0.878349   0.485700    0.849407
# 6    0.323134  0.036466   0.186775    0.509909
# 7    0.467610  0.850993   0.377558    0.845168
# 8    0.600548  0.721495   0.518241    1.118788
# 9    0.733485  0.591996   0.658924    1.392409
# 10   0.641628  0.251886   0.274987    0.916615
# 12   0.319906  0.489200   0.990319    1.310225
# 13   0.780267  0.458454   0.053428    0.833695
# 15   0.526730  0.379381   0.410849    0.937579
# 17   0.273193  0.300307   0.768270    1.041463
# 18   0.467060  0.225161   0.911570    1.378630
# 20   0.300589  0.455980   0.292225    0.592814
# 21   0.859970  0.346539   0.364629    1.224599
# 22   0.842364  0.093485   0.662066    1.504430
# 23   0.781693  0.573344   0.815692    1.597386
# 24  94.000000  0.945625  45.000000  139.000000

# %% [markdown]
# 8 Reset the index of the DataFrame object and print the number of rows.

# %%
df.reset_index(drop=True, inplace=True)
df.shape[0]
# Out:
# 17

# %% [markdown]
# 9 Make time series data with the length of a DataFrame object in the time interval you want and make it an index column.

# %%
import numpy as np

start_date = '2024-01-01'
end_date = '2024-01-10'
freq = 'D'

date_index = pd.date_range(start=start_date, end=end_date, freq=freq)
random_data = np.random.random_sample((len(date_index)))

timeseries_data = pd.DataFrame({'reading': random_data}, index=date_index)
timeseries_data
# Out:
#              reading
# 2024-01-01  0.721415
# 2024-01-02  0.651542
# 2024-01-03  0.487688
# 2024-01-04  0.261511
# 2024-01-05  0.393352
# 2024-01-06  0.738397
# 2024-01-07  0.916097
# 2024-01-08  0.881520
# 2024-01-09  0.628826
# 2024-01-10  0.197927

# %% [markdown]
# 10 Convert all values ​​in `column1` to strings with each zero replaced by an uppercase `ND` character combination.

# %%
df.column1 = df.column1.apply( lambda x: str(x).replace('0', 'ND') )

df
# Out:
#             column1   column2    column3     column4
# 0     ND.92225ND592  0.490721   0.133932    1.056182
# 1     ND.3637ND6572  0.878349   0.485700    0.849407
# 2      ND.323133868  0.036466   0.186775    0.509909
# 3     ND.4676ND9956  0.850993   0.377558    0.845168
# 4   ND.6NDND5476355  0.721495   0.518241    1.118788
# 5      ND.733485315  0.591996   0.658924    1.392409
# 6      ND.641628229  0.251886   0.274987    0.916615
# 7     ND.3199ND5543  0.489200   0.990319    1.310225
# 8     ND.78ND267224  0.458454   0.053428    0.833695
# 9   ND.52673NDND625  0.379381   0.410849    0.937579
# 10    ND.2731929ND1  0.300307   0.768270    1.041463
# 11   ND.467ND6NDND4  0.225161   0.911570    1.378630
# 12   ND.3NDND588879  0.455980   0.292225    0.592814
# 13    ND.8599699ND1  0.346539   0.364629    1.224599
# 14     ND.842364415  0.093485   0.662066    1.504430
# 15     ND.781693324  0.573344   0.815692    1.597386
# 16            94.ND  0.945625  45.000000  139.000000

# %% [markdown]
# 11 Make a copy of the DataFrame object, whose column names have been changed to the following: `column5`, `column6`, `column7`, `column8`. After that, make one big DataFrame object, which consists of the original DataFrame and a copy so that they are added next to each other.
#
#
# | column1 | column2 | column3 | column4 | column5 | column6 | column7 | column8 |
# | ------------- |:-------------:| -----:| ------------- |:-------------:| -----:|-----:|-----:|
# | 0.1 | 0.2 | 0.3 | ... | ... | ... | ... | ... |

# %%
df_copy = df.copy()
df_copy.columns = ['column5', 'column6', 'column7', 'column8']

merged_df = pd.concat([df, df_copy], axis=1)

merged_df
# Out:
#             column1   column2    column3     column4          column5  \
# 0     ND.92225ND592  0.490721   0.133932    1.056182    ND.92225ND592
# 1     ND.3637ND6572  0.878349   0.485700    0.849407    ND.3637ND6572
# 2      ND.323133868  0.036466   0.186775    0.509909     ND.323133868
# 3     ND.4676ND9956  0.850993   0.377558    0.845168    ND.4676ND9956
# 4   ND.6NDND5476355  0.721495   0.518241    1.118788  ND.6NDND5476355
# 5      ND.733485315  0.591996   0.658924    1.392409     ND.733485315
# 6      ND.641628229  0.251886   0.274987    0.916615     ND.641628229
# 7     ND.3199ND5543  0.489200   0.990319    1.310225    ND.3199ND5543
# 8     ND.78ND267224  0.458454   0.053428    0.833695    ND.78ND267224
# 9   ND.52673NDND625  0.379381   0.410849    0.937579  ND.52673NDND625
# 10    ND.2731929ND1  0.300307   0.768270    1.041463    ND.2731929ND1
# 11   ND.467ND6NDND4  0.225161   0.911570    1.378630   ND.467ND6NDND4
# 12   ND.3NDND588879  0.455980   0.292225    0.592814   ND.3NDND588879
# 13    ND.8599699ND1  0.346539   0.364629    1.224599    ND.8599699ND1
# 14     ND.842364415  0.093485   0.662066    1.504430     ND.842364415
# 15     ND.781693324  0.573344   0.815692    1.597386     ND.781693324
# 16            94.ND  0.945625  45.000000  139.000000            94.ND
#
#      column6    column7     column8
# 0   0.490721   0.133932    1.056182
# 1   0.878349   0.485700    0.849407
# 2   0.036466   0.186775    0.509909
# 3   0.850993   0.377558    0.845168
# 4   0.721495   0.518241    1.118788
# 5   0.591996   0.658924    1.392409
# 6   0.251886   0.274987    0.916615
# 7   0.489200   0.990319    1.310225
# 8   0.458454   0.053428    0.833695
# 9   0.379381   0.410849    0.937579
# 10  0.300307   0.768270    1.041463
# 11  0.225161   0.911570    1.378630
# 12  0.455980   0.292225    0.592814
# 13  0.346539   0.364629    1.224599
# 14  0.093485   0.662066    1.504430
# 15  0.573344   0.815692    1.597386
# 16  0.945625  45.000000  139.000000

# %% [markdown]
# 12 Put the last value of `column5` into a variable and the last value of `column3` into a separate variable from the newly made DataFrame object in string format. Concatenate those variables as a string and remove the last two characters from the result. Finally, remove all dots `.`.

# %%
last_in_column5 = str(merged_df.column5.iloc[-1])
last_in_column3 = str(merged_df.column3.iloc[-1])

concatenated = last_in_column5 + last_in_column3
last_two_removed = concatenated[:-2]
result = last_two_removed.replace('.', '')

result
# Out:
# '94ND45'
